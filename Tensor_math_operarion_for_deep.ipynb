# %% [markdown]
# <a href="https://colab.research.google.com/github/salihaliyi73/PyTorch-works/blob/main/Tensor_math_operarion_for_deep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TENSOR MATH OPERATIONS**

# %%
import torch

# %%
import numpy as np

# %%
#Create tensor
tensor_a=torch.tensor([1,2,3,4])
tensor_b=torch.tensor([5,6,7,8])
tensor_a
tensor_b
# Out:
# tensor([5, 6, 7, 8])

# %% [markdown]
# **Addition**

# %%
tensor_a + tensor_b
# Out:
# tensor([ 6,  8, 10, 12])

# %% [markdown]
# **Addition longhand**

# %%
torch.add(tensor_a,tensor_b)
# Out:
# tensor([ 6,  8, 10, 12])

# %% [markdown]
# **substruction**

# %%
tensor_a-tensor_b
# Out:
# tensor([-4, -4, -4, -4])

# %%
torch.sub(tensor_b,tensor_a)
# Out:
# tensor([4, 4, 4, 4])

# %%
#multiplication
tensor_a*tensor_b
# Out:
# tensor([ 5, 12, 21, 32])

# %%
torch.mul(tensor_b,tensor_a)
# Out:
# tensor([ 5, 12, 21, 32])

# %% [markdown]
# **division**
# Automatically convert it to float

# %%
tensor_b/tensor_a
# Out:
# tensor([5.0000, 3.0000, 2.3333, 2.0000])

# %% [markdown]
# **div long**

# %%
torch.div(tensor_b,tensor_a)
# Out:
# tensor([5.0000, 3.0000, 2.3333, 2.0000])

# %% [markdown]
# **Remainders**

# %%
tensor_b% tensor_a
# Out:
# tensor([0, 0, 1, 0])

# %% [markdown]
# **remainder longhand**

# %%
torch.remainder(tensor_b,tensor_a)
# Out:
# tensor([0, 0, 1, 0])

# %% [markdown]
# **Exponents/Power**

# %%
torch.pow(tensor_a,tensor_b)
# Out:
# tensor([    1,    64,  2187, 65536])

# %% [markdown]
# **ANOTHER WAY TO WRITE LOONGHAND**

# %%
tensor_a.add(tensor_b)
# Out:
# tensor([ 6,  8, 10, 12])

# %% [markdown]
# **Reassignment**

# %%
#tensor_a = tensor_a + tensor_b
tensor_a.add_(tensor_b)
# Out:
# tensor([ 6,  8, 10, 12])

# %%
tensor_a
# Out:
# tensor([ 6,  8, 10, 12])
